# %%
print (1 + 1) #soma

# %%
print(1 - 1) #subtração

# %%
print(2 * 3) #multiplicação

# %%
print(3 / 2) #divisão

# %%
print(3 // 2) #divisão inteira

# %%
print(3 % 2) #resto da divisão)

# %%
print(3 ** 2) #exponenciação)
