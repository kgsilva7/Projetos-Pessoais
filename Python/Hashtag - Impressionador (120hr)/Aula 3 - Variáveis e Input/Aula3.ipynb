# %%
print("meu nome é " + "Gustavo") #concatenação de texto

# %%
print("meu nome é" in "Gustavo") #comparação de texto

# %%
qtde_vendas = 1500 #variável inteira
print(qtde_vendas) #impressão de variável
print("eu tenho " + str(qtde_vendas) + " vendas") #concatenação de texto com variável
qtde_vendas = "1500" #variável em string
